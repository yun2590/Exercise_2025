# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit159.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import remove

target='mydata.txt'
k=input(f'<{target}>을 삭제하시겠습니까? (y/n)')
if k.lower()=='y':
  remove(target)
  print(f'<{target}>을 삭제했습니다.')
else:
  print(f'<{target}>을 삭제하지 않습니다.')
# Out:
# <mydata.txt>을 삭제하시겠습니까? (y/n)y
# <mydata.txt>을 삭제했습니다.
