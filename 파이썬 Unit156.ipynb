# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit156.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data1='This is data1'
data2='This is data2'
with open('mydata.txt','w') as f:
  f.writelines(data1)
  f.writelines(data2)

# %%
with open('mydata.txt','r') as f:
  data=f.read()
print(data)
# Out:
# This is data1This is data2

# %%
data1='This is data1\n'
data2='This is data2\n'

# %%
data=['This is data1\n','This is data2\n']
with open('mydata.txt','w') as f:
  f.writelines(data)

# %%
with open('mydata.txt','r') as f:
  data=f.read()
print(data)
# Out:
# This is data1
# This is data2
