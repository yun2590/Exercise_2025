# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit166.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from os.path import isdir

fileList=[]
dirList=[]
files=listdir('./')
for file in files:
    if isdir(file):
      dirList.append(f'<DIR> {file}')
    else:
      fileList.append(file)

fileList.sort()
dirList.sort()

for d in dirList:
  print(d)

for f in fileList:
  print(f)
# Out:
# <DIR> .config
# <DIR> .ipynb_checkpoints
# <DIR> drive
# <DIR> sample_data
# <DIR> tmp
# <DIR> tmp2
# <DIR> tmp3
# bts.mp4
# mydata.bin
# prophet_cp949_ko.txt
# prophet_en.txt
# prophet_ko.txt
# sunrise.jpg
