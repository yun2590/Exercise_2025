# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit143.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def makeException():
  raise RuntimeError('뭔가 잘못되었음')

# %%
try:
  makeException()
except Exception as e:
  print(e)
# Out:
# 뭔가 잘못되었음

# %%
try:
  makeException()
except Exception as e:
  print(e)
  raise
# Out:
# 뭔가 잘못되었음
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2653565888.py in <cell line: 0>()
#       1 try:
# ----> 2   makeException()
#       3 except Exception as e:
#       4   print(e)
#       5   raise
#
# /tmp/ipython-input-3340200797.py in makeException()
#       1 def makeException():
# ----> 2   raise RuntimeError('뭔가 잘못되었음')
#
# RuntimeError: 뭔가 잘못되었음

# %%
try:
  makeException()
except Exception as e:
  raise ValueError('값이 잘못된 것 같음')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-189609904.py in <cell line: 0>()
#       1 try:
# ----> 2   makeException()
#       3 except Exception as e:
#
# /tmp/ipython-input-3340200797.py in makeException()
#       1 def makeException():
# ----> 2   raise RuntimeError('뭔가 잘못되었음')
#
# RuntimeError: 뭔가 잘못되었음
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-189609904.py in <cell line: 0>()
#       2   makeException()
#       3 except Exception as e:
# ----> 4   raise ValueError('값이 잘못된 것 같음')
#
# ValueError: 값이 잘못된 것 같음
