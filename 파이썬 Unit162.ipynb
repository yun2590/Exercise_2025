# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit162.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import getcwd

print(f'현재 작업 디렉토리: {getcwd()}')
# Out:
# 현재 작업 디렉토리: /content

# %%
from os import chdir

print(f'현재 작업 디렉토리: {getcwd()}')
chdir('..')
print(f'현재 작업 디렉토리: {getcwd()}')
chdir('/content')
print(f'현재 작업 디렉토리: {getcwd()}')
# Out:
# 현재 작업 디렉토리: /content
# 현재 작업 디렉토리: /
# 현재 작업 디렉토리: /content
