# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=open('myfile.txt','w',encoding='cp949')
<파일 처리 코드>
f.close()

#바이너리 이미지 파일 읽기
f=open('image.jpg','rb')
<파일 처리 코드>
f.close()
