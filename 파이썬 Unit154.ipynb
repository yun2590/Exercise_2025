# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit154.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('prophet_en.txt','r') as f:
  f.seek(335)
  data=f.read()
print(data)
# Out:
# The cloud will cause two suns to appear
# The big mastiff will howl all night
# When the great pontiff will change country.
