# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit158.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import getsize

file1='sunrise.jpg'
file2='C:/data/temp/DJI_0129.MP4'
file3='../../temp/DJI_0129.MP4'

# %%
print(f'{file1}: {getsize(file1):,} 바이트')
print(f'{file2}: {getsize(file2):,} 바이트')
print(f'{file3}: {getsize(file3):,} 바이트')
# Out:
# sunrise.jpg: 240,139 바이트
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-49541015.py in <cell line: 0>()
#       1 print(f'{file1}: {getsize(file1):,} 바이트')
# ----> 2 print(f'{file2}: {getsize(file2):,} 바이트')
#       3 print(f'{file3}: {getsize(file3):,} 바이트')
#
# /usr/lib/python3.12/genericpath.py in getsize(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/data/temp/DJI_0129.MP4'
