# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit160.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import rename

src='sunris_copied.jpg'
dst='sunrise2.jpg'
rename(src,dst)

# %%
src='sunrise2.jpg'
dst='tmp/sunrise2.jpg'
rename(src,dst)
