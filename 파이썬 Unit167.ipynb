# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit167.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

with open('package.json') as f:
  data=json.load(f)
print(data)
# Out:
# {'name': 'stable-diffusion-webui', 'version': '0.0.0', 'devDependencies': {'eslint': '^8.40.0'}, 'scripts': {'lint': 'eslint .', 'fix': 'eslint --fix .'}}

# %%
profile={'name':'조조','age':45,'nationaity':'위나라','skill':['집착','배신'],'alive':True}
with open('profile.json','w') as f:
  json.dump(profile,f,indent=4)

# %%
with open('profile.json','w') as f:
  json.dump(profile,f,indent=4,ensure_ascii=False)
