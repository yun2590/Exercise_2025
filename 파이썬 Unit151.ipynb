# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit151.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open(파일경로,모드,encoding=인코딩 방식) as 파일객체:
  <파일 처리 코드>

# %%
f=open('myfile.txt','r')
readData=f.readlines()
f.close()

# %%
with open('myfile.txt','r') as f:
  readData=f.readlines()
