# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit135.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Wizard:
  def __init__(self, name=None):
    self.name = name
    print(f'마법사 이름이 <{name}>인 캐릭터가 생성되었습니다.')

  def __del__(self):
    print('Wizard 객체가 메모리에서 제거됩니다.')

# %%
player1=Wizard('StormBaby')
del player1
# Out:
# 마법사 이름이 <StormBaby>인 캐릭터가 생성되었습니다.
# Wizard 객체가 메모리에서 제거됩니다.
