# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit164.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import mkdir

folder='myfolder'
mkdir(folder)

# %%
from shutil import rmtree

folder='/content/myfolder'
k=input(f'<{folder}>를 완전히 삭제하시겠습니까? (y/n): ')
if k.lower()=='y':
  rmtree(folder)
  print(f'<{folder}>를 완전히 삭제했습니다.')
else:
  print(f'<{folder}>를 삭제하지 않습니다.')
# Out:
# </content/myfolder>를 완전히 삭제하시겠습니까? (y/n): y
# </content/myfolder>를 완전히 삭제했습니다.
