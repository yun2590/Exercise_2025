# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit134.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Wizard:
  def __init__(self):
    print('마법사 캐릭터가 생성되었습니다.')

# %%
player1=Wizard()
# Out:
# 마법사 캐릭터가 생성되었습니다.

# %%
class Wizard:
  def __init__(self,name=None):
    self.name=name
    print(f'마법사 이름이 <{self.name}>인 캐릭터가 생성되었습니다.')

# %%
player1=Wizard('StormBaby')
# Out:
# 마법사 이름이 <StormBaby>인 캐릭터가 생성되었습니다.
