# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit137.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fileList=['file01.jpg','file02.jpg','file03','file04.jpg']
for file in fileList:
  fname=file.split('.')
  print(f'파일 이름: {fname[0]}, 파일확장자: {fname[1]}')
# Out:
# 파일 이름: file01, 파일확장자: jpg
# 파일 이름: file02, 파일확장자: jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-397190829.py in <cell line: 0>()
#       2 for file in fileList:
#       3   fname=file.split('.')
# ----> 4   print(f'파일 이름: {fname[0]}, 파일확장자: {fname[1]}')
#
# IndexError: list index out of range

# %%
for file in fileList:
  try:
    fname=file.split('.')
    print(f'파일 이름: {fname[0]}, 파일확장자: {fname[1]}')
  except:
    print(f'ERROR!! <{file}> 처리중 예외 발생!')
# Out:
# 파일 이름: file01, 파일확장자: jpg
# 파일 이름: file02, 파일확장자: jpg
# ERROR!! <file03> 처리중 예외 발생!
# 파일 이름: file04, 파일확장자: jpg
