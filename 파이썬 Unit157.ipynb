# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit157.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bufsize=1024
with open('sunrise.jpg','rb') as f:
  with open('sunris_copied.jpg','wb') as h:
    data=f.read(bufsize)
    while data:
      h.write(data)
      data=f.read(bufsize)
