# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit140.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
intList=range(10)
idx=10
try:
  print(intList[idx])
except Exception as e:
  exceptionClass=e.__class__.__name__
  exceptionDetail=e.__str__()
  print(f'예외종류: {exceptionClass}, 예외내용: {exceptionDetail}')
# Out:
# 예외종류: IndexError, 예외내용: range object index out of range

# %%
intList=range(10)
idx=10
try:
  print(intList[idx])
except Exception as e:
  exceptionClass=e.__class__.__name__
  exceptionDetail=e.__str__()
  print(f'예외종류: {exceptionClass}, 예외내용: {e}')
# Out:
# 예외종류: IndexError, 예외내용: range object index out of range
