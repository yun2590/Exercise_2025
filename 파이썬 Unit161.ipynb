# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit161.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir

folder='./'
ret=listdir(folder)
print(ret)
# Out:
# ['.config', 'sunrise.jpg', '.ipynb_checkpoints', 'prophet_ko.txt', 'prophet_en.txt', 'mydata.bin', 'tmp', 'prophet_cp949_ko.txt', 'drive', 'sample_data']

# %%
from glob import glob

target='*.txt'
ret=glob(target)
print(ret)
# Out:
# ['prophet_ko.txt', 'prophet_en.txt', 'prophet_cp949_ko.txt']

# %%
target='**'
ret=glob(target,recursive=True)
ret.sort()
for r in ret:
  print(r)
# Out:
# drive
# drive/MyDrive
# drive/MyDrive/20220615_132018.jpg
# drive/MyDrive/20220720_152744.jpg
# drive/MyDrive/20220720_154947.jpg
# drive/MyDrive/20220817_134454.jpg
# drive/MyDrive/2024-10-16 00-02-09.mp4
# drive/MyDrive/2024-10-16 00-05-10.mp4
# drive/MyDrive/2024-10-16 00-13-13.mp4
# drive/MyDrive/2024-10-16 00-21-34.mp4
# drive/MyDrive/2024-10-16 00-29-43.mp4
# drive/MyDrive/2024-10-16 00-43-01.mp4
# drive/MyDrive/2024-10-16 00-56-09.mp4
# drive/MyDrive/2024-10-16 01-05-18.mp4
# drive/MyDrive/2024-10-16 01-13-00.mp4
# drive/MyDrive/2024-10-16 01-30-57.mp4
# drive/MyDrive/2024-10-16 01-37-06.mp4
# drive/MyDrive/2024-10-16 01-42-31.mp4
# drive/MyDrive/2024-10-16 01-48-36.mp4
# drive/MyDrive/2024-10-16 01-54-59.mp4
# drive/MyDrive/2024-10-16 01-59-47.mp4
# drive/MyDrive/2024-10-16 02-04-14.mp4
# drive/MyDrive/2024-10-16 02-07-59.mp4
# drive/MyDrive/2024-10-16 02-10-49.mp4
# drive/MyDrive/2024-10-16 02-14-17.mp4
# drive/MyDrive/Colab Notebooks
# ...
